# %%
import pandas as pd

# Load live and projected rankings
live = pd.read_csv("data/rankings_LIVE_L3.csv")
proj = pd.read_csv("data/rankings_L3.csv")

print("✅ Data loaded")
display(live.head(3))
display(proj.head(3))
# Out:
# ✅ Imports ready.

# %%
# Out:
# ✅ Saved rankings to: ../L3/data/rankings_L3.csv
#       INDEX              PLAYER_NORM     G   MPG   PTS   REB   AST  STL  BLK  \
# 0  10003.00        victor wembanyama 67.80 32.96 25.95 11.37  4.01 1.23 3.76
# 1  10001.00             nikola jokic 73.20 35.72 28.08 12.30 10.01 1.63 0.73
# 2  10004.00              luka doncic 70.80 35.84 30.47  8.42  8.59 1.64 0.49
# 3  10002.00  shai gilgeous alexander 74.00 33.84 32.34  5.24  6.40 1.74 0.98
# 4  10006.00            anthony davis 63.40 34.30 24.77 11.46  3.69 1.17 2.18
# 5  10005.00    giannis antetokounmpo 70.00 34.50 31.46 11.82  6.78 0.95 1.08
# 6  10021.00            derrick white 69.60 33.73 17.52  4.89  5.55 1.06 1.15
# 7  10014.00             tyrese maxey 67.40 37.82 26.09  3.51  6.09 1.46 0.41
# 8  10015.00            stephen curry 66.80 32.44 25.47  4.59  5.81 0.99 0.42
# 9  10008.00          anthony edwards 73.00 36.40 27.82  5.79  4.92 1.26 0.63
# 10 10030.00            chet holmgren 64.40 30.08 17.69  9.14  2.58 0.77 2.13
# 11 10018.00         donovan mitchell 70.80 32.11 25.63  4.72  5.40 1.43 0.35
# 12 10017.00              lamelo ball 50.80 32.71 25.57  5.56  7.86 1.29 0.30
# 13 10020.00              evan mobley 71.60 31.21 19.15  9.82  3.43 0.92 1.61
# 14 10010.00             james harden 74.60 34.56 20.74  5.51  8.45 1.33 0.71
#
#     3PM  FG%  FT%   TO  RANK_SCORE  RANK
# 0  2.26 0.50 0.82 3.51       14.92     1
# 1  1.86 0.58 0.81 3.19       13.43     2
# 2  3.60 0.48 0.78 3.77       11.21     3
# 3  1.98 0.52 0.89 2.38       11.16     4
# 4  0.73 0.52 0.79 2.33       10.40     5
# 5  0.50 0.60 0.63 3.40        8.44     6
# 6  3.37 0.44 0.86 1.86        8.27     7
# 7  3.16 0.44 0.87 2.18        8.11     8
# 8  4.55 0.45 0.93 2.88        8.07     9
# 9  3.88 0.45 0.83 3.22        8.00    10
# 10 1.69 0.50 0.77 1.87        7.98    11
# 11 3.42 0.45 0.84 2.37        7.89    12
# 12 3.86 0.42 0.85 3.68        7.64    13
# 13 1.21 0.56 0.72 2.10        7.44    14
# 14 2.84 0.42 0.87 3.71        7.22    15

# %%
# Out:
# ✅ Saved rankings to: ../L3/data/rankings_LIVE_L3.csv
#       INDEX              PLAYER_NORM    G   MPG   PTS   REB   AST  STL  BLK  \
# 0  10003.00        victor wembanyama 4.00 32.30 31.00 13.80  2.80 1.50 4.80
# 1  10004.00              luka doncic 2.00 38.00 46.00 11.50  8.50 1.00 0.50
# 2  10001.00             nikola jokic 4.00 34.30 20.30 14.50 11.30 2.00 0.50
# 3  10014.00             tyrese maxey 4.00 43.00 37.50  3.80  8.30 1.00 0.80
# 4  10015.00            stephen curry 5.00 30.40 27.00  3.80  5.00 1.80 0.80
# 5  10005.00    giannis antetokounmpo 4.00 32.80 36.30 14.00  7.00 0.80 1.30
# 6  10064.00          lauri markkanen 4.00 38.30 34.00  7.30  2.80 0.80 0.80
# 7  10017.00              lamelo ball 4.00 32.50 26.30  8.30  9.50 1.80 0.30
# 8  10040.00            austin reaves 5.00 38.20 34.20  5.60 10.00 1.80 0.00
# 9  10002.00  shai gilgeous alexander 5.00 38.60 34.80  6.20  5.40 1.40 1.40
# 10 10061.00           walker kessler 4.00 31.30 17.00 10.30  3.50 1.50 2.30
# 11 10113.00           kyshawn george 4.00 33.00 20.30  9.30  5.00 1.30 1.50
# 12 10031.00           alperen sengun 4.00 38.00 23.80  8.00  7.30 2.00 0.80
# 13 10096.00            mikal bridges 4.00 36.50 18.00  6.80  4.50 1.50 0.80
# 14 10060.00           nikola vucevic 4.00 32.50 18.30 13.30  5.00 1.00 0.30
#
#     3PM  FG%  FT%   TO  RANK_SCORE  RANK
# 0  1.00 0.60 0.80 1.50       17.34     1
# 1  3.50 0.62 0.79 3.00       12.90     2
# 2  0.80 0.57 0.93 3.00       11.60     3
# 3  4.50 0.46 0.87 2.00       11.08     4
# 4  4.40 0.51 1.00 2.20       10.05     5
# 5  1.00 0.69 0.64 3.30       10.04     6
# 6  4.00 0.51 0.91 1.00        9.80     7
# 7  4.30 0.45 0.80 4.00        9.64     8
# 8  3.00 0.53 0.90 3.80        9.16     9
# 9  1.40 0.52 0.85 2.40        8.86    10
# 10 1.50 0.75 0.70 3.30        8.75    11
# 11 3.50 0.54 0.60 2.80        8.47    12
# 12 2.00 0.49 0.79 3.00        8.44    13
# 13 2.30 0.54 0.92 0.80        8.39    14
# 14 1.80 0.58 1.00 2.00        8.09    15

# %%
# Out:
# ✅ Positive RANK_SCORE_DELTA = outperforming projections; negative = underperforming.
#
# 🏀 Top Overperformers (LIVE > PROJECTIONS):
#       INDEX        PLAYER_NORM  RANK_PROJ  RANK_LIVE  RANK_SCORE_PROJ  \
# 0  10529.00         sion james        507         86            -2.85
# 1  10361.00     nique clifford        521        107            -3.29
# 2  10268.00      cedric coward        355         42            -0.34
# 3  10189.00      dillon brooks        199         23             1.79
# 4  10096.00      mikal bridges        120         14             3.61
# 5  10113.00     kyshawn george        109         12             3.81
# 6  10040.00      austin reaves         75          9             4.65
# 7  10129.00      norman powell        138         17             3.08
# 8  10321.00       steven adams        397         85            -1.03
# 9  10451.00     svi mykhailiuk        440        101            -1.61
# 10 10064.00    lauri markkanen         47          7             5.54
# 11 10093.00      julius randle        146         21             2.88
# 12 10251.00          tre jones        176         31             2.30
# 13 10413.00        kris murray        506        172            -2.83
# 14 10134.00        kelly oubre        147         29             2.86
# 15 10204.00       ryan rollins        136         28             3.14
# 16 10504.00         will riley        548        301            -5.74
# 17 10362.00  simone fontecchio        391        113            -0.91
# 18 10393.00   collin gillespie        247         53             1.12
# 19 10146.00       aaron gordon        170         35             2.38
#
#     RANK_SCORE_LIVE  RANK_SCORE_DELTA  RANK_DELTA
# 0              3.31              6.15        -421
# 1              2.55              5.84        -414
# 2              5.15              5.49        -313
# 3              6.73              4.94        -176
# 4              8.39              4.77        -106
# 5              8.47              4.66         -97
# 6              9.16              4.51         -66
# 7              7.54              4.47        -121
# 8              3.35              4.38        -312
# 9              2.74              4.35        -339
# 10             9.80              4.26         -40
# 11             6.91              4.04        -125
# 12             6.28              3.98        -145
# 13             0.83              3.66        -334
# 14             6.44              3.58        -118
# 15             6.49              3.35        -108
# 16            -2.40              3.34        -247
# 17             2.38              3.30        -278
# 18             4.40              3.28        -194
# 19             5.65              3.27        -135
# 😬 Top Underperformers (LIVE < PROJECTIONS):
#       INDEX        PLAYER_NORM  RANK_PROJ  RANK_LIVE  RANK_SCORE_PROJ  \
# 0  10347.00      johnny juzang        243        409             1.18
# 1  10070.00       jakob poeltl         93        374             4.21
# 2  10256.00  bogdan bogdanovic        258        407             0.95
# 3  10128.00    andrew nembhard        160        387             2.55
# 4  10239.00  justin champagnie        169        384             2.40
# 5  10275.00     jordan goodwin        270        400             0.83
# 6  10106.00     isaiah jackson        112        339             3.72
# 7  10224.00     jonathan isaac        154        360             2.62
# 8  10037.00      dyson daniels         23        195             6.79
# 9  10255.00   tristan vukcevic        281        394             0.60
# 10 10241.00     karlo matkovic        265        389             0.90
# 11 10304.00      thomas bryant        228        380             1.38
# 12 10155.00       caris levert        174        351             2.34
# 13 10024.00      amen thompson         25        177             6.70
# 14 10067.00    cameron johnson         74        255             4.70
# 15 10372.00        dalen terry        443        406            -1.63
# 16 10094.00          josh hart        115        294             3.68
# 17 10158.00         lonzo ball        119        292             3.62
# 18 10114.00         tari eason         59        225             5.15
# 19 10447.00      ousmane dieng        456        405            -1.80
#
#     RANK_SCORE_LIVE  RANK_SCORE_DELTA  RANK_DELTA
# 0             -8.59             -9.76         166
# 1             -4.82             -9.03         281
# 2             -8.02             -8.97         149
# 3             -5.56             -8.11         227
# 4             -5.40             -7.80         215
# 5             -6.79             -7.62         130
# 6             -3.81             -7.53         227
# 7             -4.45             -7.08         206
# 8              0.13             -6.66         172
# 9             -6.01             -6.61         113
# 10            -5.69             -6.59         124
# 11            -5.21             -6.59         152
# 12            -4.19             -6.52         177
# 13             0.62             -6.08         152
# 14            -1.29             -5.99         181
# 15            -7.55             -5.92         -37
# 16            -2.24             -5.92         179
# 17            -2.22             -5.84         173
# 18            -0.65             -5.79         166
# 19            -7.52             -5.72         -51
