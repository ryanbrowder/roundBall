# %%
# %run ../L0/basketballReference_LIVE_L0.ipynb
# Out:
#    Rk                   Player   Age Team Pos     G    GS    MP    FG   FGA  \
# 0   1              Luka Dončić  26.0  LAL  PG  18.0  18.0  37.2  10.8  23.0
# 1   2  Shai Gilgeous-Alexander  27.0  OKC  PG  25.0  25.0  33.2  10.8  19.4
# 2   3             Tyrese Maxey  25.0  PHI  PG  23.0  23.0  39.9  10.7  22.9
# 3   4         Donovan Mitchell  29.0  CLE  SG  24.0  24.0  34.4  10.9  21.5
# 4   5             Nikola Jokić  30.0  DEN   C  24.0  24.0  34.7  10.6  17.1
#
#    ...  ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS  Awards
# 0  ...  0.8  8.2   9.0   9.0  1.5  0.6  4.3  2.6  35.0     NaN
# 1  ...  0.4  4.2   4.6   6.4  1.4  0.7  1.9  2.0  32.4     NaN
# 2  ...  0.3  4.4   4.7   7.2  1.7  0.9  2.7  2.3  31.5     NaN
# 3  ...  0.9  3.9   4.8   5.4  1.4  0.3  3.4  2.3  31.3     NaN
# 4  ...  3.0  9.3  12.3  10.9  1.4  0.8  3.4  2.8  29.5     NaN
#
# [5 rows x 31 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 31 columns):
# ...

# %%
# %run ../L1/live_L1.ipynb
# Out:
# ✅ utils.py loaded from: /Users/ryanbrowder/Documents/Fantasy/roundBall/utils/utils.py
#    INDEX                   PLAYER              PLAYER_NORM
# 0  10001             Nikola Jokic             nikola jokic
# 1  10002  Shai Gilgeous-Alexander  shai gilgeous alexander
# 2  10003        Victor Wembanyama        victor wembanyama
# 3  10004              Luka Doncic              luka doncic
# 4  10005    Giannis Antetokounmpo    giannis antetokounmpo
# 5  10006            Anthony Davis            anthony davis
# 6  10007          Cade Cunningham          cade cunningham
# 7  10008          Anthony Edwards          anthony edwards
# 8  10009       Karl-Anthony Towns       karl anthony towns
# 9  10010             James Harden             james harden
# Rows: 547 | Unique INDEX: 547
#                     PLAYER     G   MPG   PTS   FGM   FGA    FG%   FTA  FTM  \
# 0              Luka Dončić  18.0  37.2  35.0  10.8  23.0  0.471  12.2  9.8
# ...

# %%
# %run rankings_L2.ipynb
# Out:
# ✅ Imports ready.
# ✅ Paths and config set.
# ℹ️ USE_WEIGHTS=False — proceeding with unweighted z-score sum.
# ✅ Saved rankings to: /Users/ryanbrowder/Documents/Fantasy/roundBall/L3/data/rankings_L3.csv
#       INDEX              PLAYER_NORM     G   MPG   PTS   REB   AST  STL  BLK  \
# 0  10003.00        victor wembanyama 67.80 32.96 25.95 11.37  4.01 1.23 3.76
# 1  10001.00             nikola jokic 73.20 35.72 28.08 12.30 10.01 1.63 0.73
# 2  10004.00              luka doncic 70.80 35.84 30.47  8.42  8.59 1.64 0.49
# 3  10002.00  shai gilgeous alexander 74.00 33.84 32.34  5.24  6.40 1.74 0.98
# 4  10006.00            anthony davis 63.40 34.30 24.77 11.46  3.69 1.17 2.18
# 5  10005.00    giannis antetokounmpo 70.00 34.50 31.46 11.82  6.78 0.95 1.08
# 6  10021.00            derrick white 69.60 33.73 17.52  4.89  5.55 1.06 1.15
# 7  10014.00             tyrese maxey 67.40 37.82 26.09  3.51  6.09 1.46 0.41
# 8  10015.00            stephen curry 66.80 32.44 25.47  4.59  5.81 0.99 0.42
# ...
