# %%
import numpy as np
import pandas as pd
from IPython.display import display

# %%
import numpy as np
import pandas as pd
from IPython.display import display

import sys
sys.path.append("../utils")

from utils import load_bref_per_game

SEASON = 2026
CACHE_PATH = "data/basketballReference_LIVE_L0.csv"

df_basketballReference = load_bref_per_game(SEASON, cache_path=CACHE_PATH)

display(df_basketballReference.head(5))
display(df_basketballReference.info())
# Out:
#    Rk                   Player   Age Team Pos     G    GS    MP    FG   FGA  \
# 0   1              Luka Dončić  26.0  LAL  PG  17.0  17.0  37.1  10.8  22.9
# 1   2  Shai Gilgeous-Alexander  27.0  OKC  PG  23.0  23.0  33.3  10.8  19.4
# 2   3             Tyrese Maxey  25.0  PHI  PG  23.0  23.0  39.9  10.7  22.9
# 3   4         Donovan Mitchell  29.0  CLE  SG  23.0  23.0  34.3  10.6  21.1
# 4   5             Nikola Jokić  30.0  DEN   C  23.0  23.0  34.9  10.5  17.1
#
#    ...  ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS  Awards
# 0  ...  0.8  8.4   9.2   9.1  1.5  0.6  4.4  2.5  35.0     NaN
# 1  ...  0.5  4.3   4.7   6.4  1.4  0.7  1.7  2.0  32.8     NaN
# 2  ...  0.3  4.4   4.7   7.2  1.7  0.9  2.7  2.3  31.5     NaN
# 3  ...  1.0  3.9   4.8   5.5  1.4  0.3  3.4  2.4  30.5     NaN
# 4  ...  3.0  9.3  12.3  11.0  1.3  0.8  3.5  2.8  29.2     NaN
#
# [5 rows x 31 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      499 non-null    Int64
#  1   Player  500 non-null    object
#  2   Age     499 non-null    float64
#  3   Team    499 non-null    object
#  4   Pos     499 non-null    object
#  5   G       499 non-null    float64
#  6   GS      499 non-null    float64
#  7   MP      499 non-null    float64
#  8   FG      499 non-null    float64
#  9   FGA     499 non-null    float64
#  10  FG%     498 non-null    float64
#  11  3P      499 non-null    float64
#  12  3PA     499 non-null    float64
#  13  3P%     458 non-null    float64
#  14  2P      499 non-null    float64
#  15  2PA     499 non-null    float64
#  16  2P%     488 non-null    float64
#  17  eFG%    498 non-null    float64
#  18  FT      499 non-null    float64
#  19  FTA     499 non-null    float64
#  20  FT%     452 non-null    float64
#  21  ORB     499 non-null    float64
#  22  DRB     499 non-null    float64
#  23  TRB     499 non-null    float64
#  24  AST     499 non-null    float64
#  25  STL     499 non-null    float64
#  26  BLK     499 non-null    float64
#  27  TOV     499 non-null    float64
#  28  PF      499 non-null    float64
#  29  PTS     499 non-null    float64
#  30  Awards  0 non-null      float64
# dtypes: Int64(1), float64(27), object(3)
# memory usage: 121.7+ KB
# None

# %%
#df_basketballReference = pd.read_csv('data/basketballReference_LIVE_L0.csv')

#display(df_basketballReference.head(5))
#display(df_basketballReference.info())

# %%
# Rename 'Player' to 'PLAYER' if it exists
df_basketballReference = df_basketballReference.rename(columns={'Player': 'PLAYER'})
df_basketballReference = df_basketballReference.rename(columns={'MP': 'MPG'})
df_basketballReference = df_basketballReference.rename(columns={'FG': 'FGM'})
df_basketballReference = df_basketballReference.rename(columns={'FT': 'FTM'})
df_basketballReference = df_basketballReference.rename(columns={'3P': '3PM'})
df_basketballReference = df_basketballReference.rename(columns={'TRB': 'REB'})
df_basketballReference = df_basketballReference.rename(columns={'TOV': 'TO'})

# Define the exact column order to keep
keep_cols = [
    "PLAYER", "G", "MPG","PTS", "FGM", "FGA", "FG%", 
    "FTA", "FTM", "FT%", "3PM", "REB", 
    "AST", "STL", "BLK", "TO"
]

# Filter and reorder safely
df_basketballReference = df_basketballReference[
    [col for col in keep_cols if col in df_basketballReference.columns]
]

# %%
numeric_cols = [
        'G','MPG','PTS',
        'FGM', 'FGA', 'FG%', 
        'FTA', 'FTM', 'FT%', 
        '3PM', 'REB', 'AST', 'STL', 'BLK', 'TO'
]

# Convert safely — non-numeric entries become NaN
for col in numeric_cols:
    df_basketballReference[col] = pd.to_numeric(df_basketballReference[col], errors='coerce')

# %%
display(df_basketballReference.head(5))
display(df_basketballReference.info())
# Out:
#                     PLAYER     G   MPG   PTS   FGM   FGA    FG%   FTA  FTM  \
# 0              Luka Dončić  17.0  37.1  35.0  10.8  22.9  0.472  12.1  9.8
# 1  Shai Gilgeous-Alexander  23.0  33.3  32.8  10.8  19.4  0.556  10.2  9.0
# 2             Tyrese Maxey  23.0  39.9  31.5  10.7  22.9  0.467   7.3  6.4
# 3         Donovan Mitchell  23.0  34.3  30.5  10.6  21.1  0.502   6.3  5.3
# 4             Nikola Jokić  23.0  34.9  29.2  10.5  17.1  0.612   7.2  6.1
#
#      FT%  3PM   REB   AST  STL  BLK   TO
# 0  0.810  3.6   9.2   9.1  1.5  0.6  4.4
# 1  0.881  2.2   4.7   6.4  1.4  0.7  1.7
# 2  0.881  3.7   4.7   7.2  1.7  0.9  2.7
# 3  0.836  4.0   4.8   5.5  1.4  0.3  3.4
# 4  0.855  2.1  12.3  11.0  1.3  0.8  3.5
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PLAYER  500 non-null    object
#  1   G       499 non-null    float64
#  2   MPG     499 non-null    float64
#  3   PTS     499 non-null    float64
#  4   FGM     499 non-null    float64
#  5   FGA     499 non-null    float64
#  6   FG%     498 non-null    float64
#  7   FTA     499 non-null    float64
#  8   FTM     499 non-null    float64
#  9   FT%     452 non-null    float64
#  10  3PM     499 non-null    float64
#  11  REB     499 non-null    float64
#  12  AST     499 non-null    float64
#  13  STL     499 non-null    float64
#  14  BLK     499 non-null    float64
#  15  TO      499 non-null    float64
# dtypes: float64(15), object(1)
# memory usage: 62.6+ KB
# None

# %%
# Convert to csv

df_basketballReference.to_csv("../L1/data/basketballReference_LIVE_L1.csv")
