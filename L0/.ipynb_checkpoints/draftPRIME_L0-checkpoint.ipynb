# %%
# mass L0 run

# %%
import numpy as np
import pandas as pd
from IPython.display import display

# %%
# %run basketballReference_L0.ipynb
# %run fanScout_L0.ipynb
# %run fantasyPros_L0.ipynb
# %run hashTag_L0.ipynb
# Out:
#   Unnamed: 0        Unnamed: 1 Unnamed: 2 Per 36 Minutes Per 36 Minutes.1  \
# 0         Rk            Player       Type             FG              FGA
# 1          1  Precious Achiuwa  Projected            5.3             10.6
# 2          2      Steven Adams  Projected            4.5              8.5
# 3          3       Bam Adebayo  Projected            7.5               15
# 4          4      Ochai Agbaji  Projected            5.1             10.8
#
#   Per 36 Minutes.2 Per 36 Minutes.3 Per 36 Minutes.4 Per 36 Minutes.5  \
# 0               3P              3PA               FT              FTA
# 1              0.6                2              1.6              2.5
# 2              0.3              0.9              1.9              4.1
# 3              0.8              2.2              3.7              4.8
# 4              1.9              5.2              0.9              1.3
#
#   Per 36 Minutes.6  ... Per 36 Minutes.8 Per 36 Minutes.9 Per 36 Minutes.10  \
# ...
